# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

# untuk mendapatkan hasil yang konsisten setelah beberapa kali dijalankan
tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

# 0 for benign, 1 for malignant
class_names = ["benign", "malignant"]


def download_and_extract_dataset():
  # dataset from https://github.com/udacity/dermatologist-ai
  # 5.3GB
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  # 824.5MB
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  # 5.1GB
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")
    # remove the temp file
    os.remove(temp_file)

# comment the below line if you already downloaded the dataset
download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864538487/864538487 [==============================] - 53s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736557430/5736557430 [==============================] - 349s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528640507/5528640507 [==============================] - 332s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %%
# preparing data
# menghasilkan file metadata CSV untuk membaca jalur img dan label darinya
def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder) # mengambil nama folder terakhir
    labels = list(label2int)
    # generate CSV file
    df = pd.DataFrame(columns=["filepath", "label"]) # membuat dataframe dengan kolom filepath dan label
    i = 0
    for label in labels: # melakukan perulangan untuk mengecek setiap file dalam folder-folder yang ada di dalam data
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]] # memasukkan setiap baris data ke dataframe
            i += 1
    output_file = f"{folder_name}.csv" # menghasilkan nama file berdasarkan folder yang ada pada parameter
    print("Saving", output_file)
    df.to_csv(output_file) # menyimpan dataset ke dalam bentuk csv


generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train/nevus/*
# Reading data/train/seborrheic_keratosis/*
# Reading data/train/melanoma/*
# Saving train.csv
# Reading data/valid/nevus/*
# Reading data/valid/seborrheic_keratosis/*
# Reading data/valid/melanoma/*
# Saving valid.csv
# Reading data/test/nevus/*
# Reading data/test/seborrheic_keratosis/*
# Reading data/test/melanoma/*
# Saving test.csv

# %%
# loading data
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
# load CSV files as DataFrames
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %%
# preprocess data
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  # load the raw data from the file as a string
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label


valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
# test_ds = test_ds
for image, label in train_ds.take(1):
    print("Image shape:", image.shape)
    print("Label:", label.numpy())
# Out:
# Image shape: (299, 299, 3)
# Label: 0

# %%
# training parameters
batch_size = 64
optimizer = "rmsprop"

# %%
def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  # shuffle the dataset
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  # Repeat forever
  ds = ds.repeat()
  # split to batches
  ds = ds.batch(batch_size)

  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

  return ds


valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')

show_batch(batch)

# %%
# building the model
# InceptionV3 model & pre-trained weights
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4" #URL modul untuk InceptionV3
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))
# saves model checkpoint whenever we reach better weights
modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds,
                steps_per_epoch=n_training_samples // batch_size,
                validation_steps=n_validation_samples // batch_size, verbose=1, epochs=100,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8019
# Epoch 1: val_loss improved from inf to 0.53276, saving model to benign-vs-malignant_64_rmsprop_0.533.h5
# 31/31 [==============================] - 267s 4s/step - loss: 0.4084 - accuracy: 0.8019 - val_loss: 0.5328 - val_accuracy: 0.7578
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3951 - accuracy: 0.8286
# Epoch 2: val_loss improved from 0.53276 to 0.45763, saving model to benign-vs-malignant_64_rmsprop_0.458.h5
# 31/31 [==============================] - 19s 619ms/step - loss: 0.3951 - accuracy: 0.8286 - val_loss: 0.4576 - val_accuracy: 0.8203
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3795 - accuracy: 0.8256
# Epoch 3: val_loss did not improve from 0.45763
# 31/31 [==============================] - 9s 293ms/step - loss: 0.3795 - accuracy: 0.8256 - val_loss: 0.4777 - val_accuracy: 0.7422
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8332
# Epoch 4: val_loss did not improve from 0.45763
# 31/31 [==============================] - 10s 325ms/step - loss: 0.3614 - accuracy: 0.8332 - val_loss: 0.4956 - val_accuracy: 0.7812
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8458
# Epoch 5: val_loss did not improve from 0.45763
# 31/31 [==============================] - 9s 282ms/step - loss: 0.3583 - accuracy: 0.8458 - val_loss: 0.4588 - val_accuracy: 0.7734
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.8372
# Epoch 6: val_loss improved from 0.45763 to 0.45689, saving model to benign-vs-malignant_64_rmsprop_0.457.h5
# 31/31 [==============================] - 9s 293ms/step - loss: 0.3521 - accuracy: 0.8372 - val_loss: 0.4569 - val_accuracy: 0.7812
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.8443
# Epoch 7: val_loss did not improve from 0.45689
# 31/31 [==============================] - 8s 264ms/step - loss: 0.3424 - accuracy: 0.8443 - val_loss: 0.4646 - val_accuracy: 0.7969
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8579
# Epoch 8: val_loss improved from 0.45689 to 0.43878, saving model to benign-vs-malignant_64_rmsprop_0.439.h5
# 31/31 [==============================] - 9s 282ms/step - loss: 0.3350 - accuracy: 0.8579 - val_loss: 0.4388 - val_accuracy: 0.8203
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3425 - accuracy: 0.8397
# Epoch 9: val_loss improved from 0.43878 to 0.42838, saving model to benign-vs-malignant_64_rmsprop_0.428.h5
# 31/31 [==============================] - 9s 282ms/step - loss: 0.3425 - accuracy: 0.8397 - val_loss: 0.4284 - val_accuracy: 0.8047
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.8427
# Epoch 10: val_loss did not improve from 0.42838
# 31/31 [==============================] - 8s 276ms/step - loss: 0.3309 - accuracy: 0.8427 - val_loss: 0.4768 - val_accuracy: 0.7656
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8594
# Epoch 11: val_loss did not improve from 0.42838
# 31/31 [==============================] - 8s 266ms/step - loss: 0.3185 - accuracy: 0.8594 - val_loss: 0.4442 - val_accuracy: 0.7891
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.8553
# Epoch 12: val_loss did not improve from 0.42838
# 31/31 [==============================] - 13s 417ms/step - loss: 0.3373 - accuracy: 0.8553 - val_loss: 0.4411 - val_accuracy: 0.8125
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3428 - accuracy: 0.8458
# Epoch 13: val_loss did not improve from 0.42838
# 31/31 [==============================] - 9s 281ms/step - loss: 0.3428 - accuracy: 0.8458 - val_loss: 0.4541 - val_accuracy: 0.7891
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3067 - accuracy: 0.8684
# Epoch 14: val_loss did not improve from 0.42838
# 31/31 [==============================] - 9s 285ms/step - loss: 0.3067 - accuracy: 0.8684 - val_loss: 0.4653 - val_accuracy: 0.7656
# Epoch 15/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8629
# Epoch 15: val_loss did not improve from 0.42838
# 31/31 [==============================] - 10s 329ms/step - loss: 0.3176 - accuracy: 0.8629 - val_loss: 0.4451 - val_accuracy: 0.8047
# Epoch 16/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8639
# Epoch 16: val_loss did not improve from 0.42838
# 31/31 [==============================] - 10s 338ms/step - loss: 0.3161 - accuracy: 0.8639 - val_loss: 0.4600 - val_accuracy: 0.7969
# Epoch 17/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3286 - accuracy: 0.8518
# Epoch 17: val_loss did not improve from 0.42838
# 31/31 [==============================] - 9s 284ms/step - loss: 0.3286 - accuracy: 0.8518 - val_loss: 0.4488 - val_accuracy: 0.8203
# Epoch 18/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3086 - accuracy: 0.8755
# Epoch 18: val_loss did not improve from 0.42838
# 31/31 [==============================] - 17s 547ms/step - loss: 0.3086 - accuracy: 0.8755 - val_loss: 0.4712 - val_accuracy: 0.7422
# Epoch 19/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8700
# Epoch 19: val_loss improved from 0.42838 to 0.41672, saving model to benign-vs-malignant_64_rmsprop_0.417.h5
# 31/31 [==============================] - 11s 345ms/step - loss: 0.3071 - accuracy: 0.8700 - val_loss: 0.4167 - val_accuracy: 0.8203
# Epoch 20/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3096 - accuracy: 0.8594
# Epoch 20: val_loss did not improve from 0.41672
# 31/31 [==============================] - 9s 277ms/step - loss: 0.3096 - accuracy: 0.8594 - val_loss: 0.4277 - val_accuracy: 0.8203
# Epoch 21/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2968 - accuracy: 0.8740
# Epoch 21: val_loss did not improve from 0.41672
# 31/31 [==============================] - 9s 285ms/step - loss: 0.2968 - accuracy: 0.8740 - val_loss: 0.4366 - val_accuracy: 0.7891
# Epoch 22/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8684
# Epoch 22: val_loss did not improve from 0.41672
# 31/31 [==============================] - 9s 285ms/step - loss: 0.3011 - accuracy: 0.8684 - val_loss: 0.4910 - val_accuracy: 0.7656
# Epoch 23/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.8664
# Epoch 23: val_loss did not improve from 0.41672
# 31/31 [==============================] - 8s 275ms/step - loss: 0.3008 - accuracy: 0.8664 - val_loss: 0.4638 - val_accuracy: 0.7891
# Epoch 24/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 0.8619
# Epoch 24: val_loss did not improve from 0.41672
# 31/31 [==============================] - 11s 342ms/step - loss: 0.3026 - accuracy: 0.8619 - val_loss: 0.4609 - val_accuracy: 0.7969
# Epoch 25/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.8775
# Epoch 25: val_loss did not improve from 0.41672
# 31/31 [==============================] - 9s 287ms/step - loss: 0.2861 - accuracy: 0.8775 - val_loss: 0.4403 - val_accuracy: 0.7891
# Epoch 26/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8639
# Epoch 26: val_loss did not improve from 0.41672
# 31/31 [==============================] - 11s 353ms/step - loss: 0.3069 - accuracy: 0.8639 - val_loss: 0.4187 - val_accuracy: 0.8203
# Epoch 27/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2820 - accuracy: 0.8795
# Epoch 27: val_loss did not improve from 0.41672
# 31/31 [==============================] - 16s 539ms/step - loss: 0.2820 - accuracy: 0.8795 - val_loss: 0.4334 - val_accuracy: 0.8125
# Epoch 28/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.8760
# Epoch 28: val_loss did not improve from 0.41672
# 31/31 [==============================] - 13s 438ms/step - loss: 0.2765 - accuracy: 0.8760 - val_loss: 0.4679 - val_accuracy: 0.8281
# Epoch 29/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3044 - accuracy: 0.8720
# Epoch 29: val_loss did not improve from 0.41672
# 31/31 [==============================] - 13s 410ms/step - loss: 0.3044 - accuracy: 0.8720 - val_loss: 0.4497 - val_accuracy: 0.8281
# Epoch 30/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.8780
# Epoch 30: val_loss did not improve from 0.41672
# 31/31 [==============================] - 10s 314ms/step - loss: 0.2807 - accuracy: 0.8780 - val_loss: 0.4577 - val_accuracy: 0.7500
# Epoch 31/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.8770
# Epoch 31: val_loss did not improve from 0.41672
# 31/31 [==============================] - 14s 467ms/step - loss: 0.2882 - accuracy: 0.8770 - val_loss: 0.4615 - val_accuracy: 0.7969
# Epoch 32/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.8841
# Epoch 32: val_loss did not improve from 0.41672
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2803 - accuracy: 0.8841 - val_loss: 0.4308 - val_accuracy: 0.7891
# Epoch 33/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.8810
# Epoch 33: val_loss improved from 0.41672 to 0.41489, saving model to benign-vs-malignant_64_rmsprop_0.415.h5
# 31/31 [==============================] - 11s 356ms/step - loss: 0.2864 - accuracy: 0.8810 - val_loss: 0.4149 - val_accuracy: 0.8047
# Epoch 34/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.8816
# Epoch 34: val_loss did not improve from 0.41489
# 31/31 [==============================] - 10s 324ms/step - loss: 0.2783 - accuracy: 0.8816 - val_loss: 0.4573 - val_accuracy: 0.8047
# Epoch 35/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2759 - accuracy: 0.8846
# Epoch 35: val_loss did not improve from 0.41489
# 31/31 [==============================] - 12s 408ms/step - loss: 0.2759 - accuracy: 0.8846 - val_loss: 0.4484 - val_accuracy: 0.8203
# Epoch 36/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2802 - accuracy: 0.8780
# Epoch 36: val_loss did not improve from 0.41489
# 31/31 [==============================] - 17s 574ms/step - loss: 0.2802 - accuracy: 0.8780 - val_loss: 0.5054 - val_accuracy: 0.6875
# Epoch 37/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8836
# Epoch 37: val_loss did not improve from 0.41489
# 31/31 [==============================] - 12s 401ms/step - loss: 0.2799 - accuracy: 0.8836 - val_loss: 0.4393 - val_accuracy: 0.8047
# Epoch 38/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2816 - accuracy: 0.8725
# Epoch 38: val_loss did not improve from 0.41489
# 31/31 [==============================] - 11s 372ms/step - loss: 0.2816 - accuracy: 0.8725 - val_loss: 0.4715 - val_accuracy: 0.7656
# Epoch 39/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.8826
# Epoch 39: val_loss did not improve from 0.41489
# 31/31 [==============================] - 11s 367ms/step - loss: 0.2768 - accuracy: 0.8826 - val_loss: 0.4563 - val_accuracy: 0.8125
# Epoch 40/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.8987
# Epoch 40: val_loss did not improve from 0.41489
# 31/31 [==============================] - 17s 568ms/step - loss: 0.2688 - accuracy: 0.8987 - val_loss: 0.4380 - val_accuracy: 0.8125
# Epoch 41/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8775
# Epoch 41: val_loss did not improve from 0.41489
# 31/31 [==============================] - 12s 385ms/step - loss: 0.2846 - accuracy: 0.8775 - val_loss: 0.4393 - val_accuracy: 0.8047
# Epoch 42/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.8841
# Epoch 42: val_loss did not improve from 0.41489
# 31/31 [==============================] - 11s 356ms/step - loss: 0.2702 - accuracy: 0.8841 - val_loss: 0.4338 - val_accuracy: 0.8125
# Epoch 43/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.8866
# Epoch 43: val_loss did not improve from 0.41489
# 31/31 [==============================] - 10s 341ms/step - loss: 0.2738 - accuracy: 0.8866 - val_loss: 0.4669 - val_accuracy: 0.7969
# Epoch 44/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.8967
# Epoch 44: val_loss did not improve from 0.41489
# 31/31 [==============================] - 14s 464ms/step - loss: 0.2597 - accuracy: 0.8967 - val_loss: 0.4306 - val_accuracy: 0.8203
# Epoch 45/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.8836
# Epoch 45: val_loss did not improve from 0.41489
# 31/31 [==============================] - 13s 411ms/step - loss: 0.2780 - accuracy: 0.8836 - val_loss: 0.4176 - val_accuracy: 0.8047
# Epoch 46/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2612 - accuracy: 0.8886
# Epoch 46: val_loss did not improve from 0.41489
# 31/31 [==============================] - 16s 530ms/step - loss: 0.2612 - accuracy: 0.8886 - val_loss: 0.4624 - val_accuracy: 0.7891
# Epoch 47/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2721 - accuracy: 0.8836
# Epoch 47: val_loss did not improve from 0.41489
# 31/31 [==============================] - 10s 316ms/step - loss: 0.2721 - accuracy: 0.8836 - val_loss: 0.4660 - val_accuracy: 0.7969
# Epoch 48/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.8936
# Epoch 48: val_loss did not improve from 0.41489
# 31/31 [==============================] - 24s 802ms/step - loss: 0.2603 - accuracy: 0.8936 - val_loss: 0.4639 - val_accuracy: 0.8203
# Epoch 49/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.8846
# Epoch 49: val_loss did not improve from 0.41489
# 31/31 [==============================] - 24s 786ms/step - loss: 0.2738 - accuracy: 0.8846 - val_loss: 0.4893 - val_accuracy: 0.7891
# Epoch 50/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9002
# Epoch 50: val_loss did not improve from 0.41489
# 31/31 [==============================] - 11s 350ms/step - loss: 0.2493 - accuracy: 0.9002 - val_loss: 0.4227 - val_accuracy: 0.8203
# Epoch 51/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2660 - accuracy: 0.8911
# Epoch 51: val_loss improved from 0.41489 to 0.39868, saving model to benign-vs-malignant_64_rmsprop_0.399.h5
# 31/31 [==============================] - 29s 949ms/step - loss: 0.2660 - accuracy: 0.8911 - val_loss: 0.3987 - val_accuracy: 0.8281
# Epoch 52/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.8962
# Epoch 52: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 405ms/step - loss: 0.2563 - accuracy: 0.8962 - val_loss: 0.4230 - val_accuracy: 0.8359
# Epoch 53/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.8911
# Epoch 53: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 404ms/step - loss: 0.2571 - accuracy: 0.8911 - val_loss: 0.4047 - val_accuracy: 0.8359
# Epoch 54/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2697 - accuracy: 0.8881
# Epoch 54: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 408ms/step - loss: 0.2697 - accuracy: 0.8881 - val_loss: 0.4457 - val_accuracy: 0.8125
# Epoch 55/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9042
# Epoch 55: val_loss did not improve from 0.39868
# 31/31 [==============================] - 19s 619ms/step - loss: 0.2531 - accuracy: 0.9042 - val_loss: 0.4614 - val_accuracy: 0.7969
# Epoch 56/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2393 - accuracy: 0.9017
# Epoch 56: val_loss did not improve from 0.39868
# 31/31 [==============================] - 18s 577ms/step - loss: 0.2393 - accuracy: 0.9017 - val_loss: 0.4236 - val_accuracy: 0.8125
# Epoch 57/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.8957
# Epoch 57: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 405ms/step - loss: 0.2527 - accuracy: 0.8957 - val_loss: 0.4510 - val_accuracy: 0.8047
# Epoch 58/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.8977
# Epoch 58: val_loss did not improve from 0.39868
# 31/31 [==============================] - 10s 315ms/step - loss: 0.2542 - accuracy: 0.8977 - val_loss: 0.4232 - val_accuracy: 0.8359
# Epoch 59/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.8891
# Epoch 59: val_loss did not improve from 0.39868
# 31/31 [==============================] - 10s 331ms/step - loss: 0.2644 - accuracy: 0.8891 - val_loss: 0.4553 - val_accuracy: 0.7969
# Epoch 60/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2437 - accuracy: 0.9037
# Epoch 60: val_loss did not improve from 0.39868
# 31/31 [==============================] - 21s 696ms/step - loss: 0.2437 - accuracy: 0.9037 - val_loss: 0.4710 - val_accuracy: 0.7734
# Epoch 61/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.8957
# Epoch 61: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 374ms/step - loss: 0.2543 - accuracy: 0.8957 - val_loss: 0.3997 - val_accuracy: 0.8203
# Epoch 62/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.8886
# Epoch 62: val_loss did not improve from 0.39868
# 31/31 [==============================] - 17s 554ms/step - loss: 0.2627 - accuracy: 0.8886 - val_loss: 0.4709 - val_accuracy: 0.7891
# Epoch 63/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.8987
# Epoch 63: val_loss did not improve from 0.39868
# 31/31 [==============================] - 14s 454ms/step - loss: 0.2524 - accuracy: 0.8987 - val_loss: 0.4596 - val_accuracy: 0.8125
# Epoch 64/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.8982
# Epoch 64: val_loss did not improve from 0.39868
# 31/31 [==============================] - 15s 482ms/step - loss: 0.2541 - accuracy: 0.8982 - val_loss: 0.5124 - val_accuracy: 0.7891
# Epoch 65/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.8972
# Epoch 65: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 415ms/step - loss: 0.2575 - accuracy: 0.8972 - val_loss: 0.4059 - val_accuracy: 0.8359
# Epoch 66/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9073
# Epoch 66: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 424ms/step - loss: 0.2384 - accuracy: 0.9073 - val_loss: 0.4440 - val_accuracy: 0.8203
# Epoch 67/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2453 - accuracy: 0.9057
# Epoch 67: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 379ms/step - loss: 0.2453 - accuracy: 0.9057 - val_loss: 0.4578 - val_accuracy: 0.8125
# Epoch 68/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2453 - accuracy: 0.8992
# Epoch 68: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 358ms/step - loss: 0.2453 - accuracy: 0.8992 - val_loss: 0.4528 - val_accuracy: 0.8281
# Epoch 69/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.9012
# Epoch 69: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 388ms/step - loss: 0.2460 - accuracy: 0.9012 - val_loss: 0.4308 - val_accuracy: 0.8281
# Epoch 70/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.8977
# Epoch 70: val_loss did not improve from 0.39868
# 31/31 [==============================] - 18s 583ms/step - loss: 0.2503 - accuracy: 0.8977 - val_loss: 0.4325 - val_accuracy: 0.8203
# Epoch 71/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2268 - accuracy: 0.9083
# Epoch 71: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 383ms/step - loss: 0.2268 - accuracy: 0.9083 - val_loss: 0.4317 - val_accuracy: 0.8359
# Epoch 72/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.9017
# Epoch 72: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 385ms/step - loss: 0.2454 - accuracy: 0.9017 - val_loss: 0.4598 - val_accuracy: 0.8203
# Epoch 73/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.8962
# Epoch 73: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 386ms/step - loss: 0.2466 - accuracy: 0.8962 - val_loss: 0.6665 - val_accuracy: 0.8047
# Epoch 74/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.8997
# Epoch 74: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 384ms/step - loss: 0.2496 - accuracy: 0.8997 - val_loss: 0.4495 - val_accuracy: 0.8516
# Epoch 75/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9108
# Epoch 75: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 417ms/step - loss: 0.2310 - accuracy: 0.9108 - val_loss: 0.5354 - val_accuracy: 0.8359
# Epoch 76/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.9042
# Epoch 76: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 382ms/step - loss: 0.2366 - accuracy: 0.9042 - val_loss: 0.7673 - val_accuracy: 0.7891
# Epoch 77/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.8916
# Epoch 77: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 377ms/step - loss: 0.2542 - accuracy: 0.8916 - val_loss: 0.6772 - val_accuracy: 0.7969
# Epoch 78/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9017
# Epoch 78: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 416ms/step - loss: 0.2414 - accuracy: 0.9017 - val_loss: 0.6173 - val_accuracy: 0.8203
# Epoch 79/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9042
# Epoch 79: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 380ms/step - loss: 0.2346 - accuracy: 0.9042 - val_loss: 0.8331 - val_accuracy: 0.7812
# Epoch 80/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9057
# Epoch 80: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 375ms/step - loss: 0.2312 - accuracy: 0.9057 - val_loss: 0.8454 - val_accuracy: 0.7891
# Epoch 81/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9073
# Epoch 81: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 372ms/step - loss: 0.2347 - accuracy: 0.9073 - val_loss: 0.7779 - val_accuracy: 0.7969
# Epoch 82/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9057
# Epoch 82: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 410ms/step - loss: 0.2337 - accuracy: 0.9057 - val_loss: 0.8093 - val_accuracy: 0.7969
# Epoch 83/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9103
# Epoch 83: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 386ms/step - loss: 0.2330 - accuracy: 0.9103 - val_loss: 0.8928 - val_accuracy: 0.8047
# Epoch 84/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2463 - accuracy: 0.8962
# Epoch 84: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 416ms/step - loss: 0.2463 - accuracy: 0.8962 - val_loss: 0.8267 - val_accuracy: 0.7969
# Epoch 85/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9012
# Epoch 85: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 417ms/step - loss: 0.2414 - accuracy: 0.9012 - val_loss: 0.8076 - val_accuracy: 0.8125
# Epoch 86/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.9093
# Epoch 86: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 376ms/step - loss: 0.2288 - accuracy: 0.9093 - val_loss: 0.9646 - val_accuracy: 0.7891
# Epoch 87/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9062
# Epoch 87: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 386ms/step - loss: 0.2357 - accuracy: 0.9062 - val_loss: 0.8574 - val_accuracy: 0.8047
# Epoch 88/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9007
# Epoch 88: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 376ms/step - loss: 0.2385 - accuracy: 0.9007 - val_loss: 0.9379 - val_accuracy: 0.7812
# Epoch 89/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9118
# Epoch 89: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 370ms/step - loss: 0.2263 - accuracy: 0.9118 - val_loss: 0.8330 - val_accuracy: 0.8125
# Epoch 90/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2369 - accuracy: 0.9068
# Epoch 90: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 411ms/step - loss: 0.2369 - accuracy: 0.9068 - val_loss: 0.8068 - val_accuracy: 0.8125
# Epoch 91/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9153
# Epoch 91: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 383ms/step - loss: 0.2251 - accuracy: 0.9153 - val_loss: 0.8265 - val_accuracy: 0.8125
# Epoch 92/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9042
# Epoch 92: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 370ms/step - loss: 0.2344 - accuracy: 0.9042 - val_loss: 0.8512 - val_accuracy: 0.7969
# Epoch 93/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9052
# Epoch 93: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 376ms/step - loss: 0.2405 - accuracy: 0.9052 - val_loss: 0.7429 - val_accuracy: 0.7969
# Epoch 94/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9068
# Epoch 94: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 387ms/step - loss: 0.2256 - accuracy: 0.9068 - val_loss: 0.8137 - val_accuracy: 0.8047
# Epoch 95/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9088
# Epoch 95: val_loss did not improve from 0.39868
# 31/31 [==============================] - 12s 377ms/step - loss: 0.2280 - accuracy: 0.9088 - val_loss: 0.8019 - val_accuracy: 0.8203
# Epoch 96/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2327 - accuracy: 0.9103
# Epoch 96: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 367ms/step - loss: 0.2327 - accuracy: 0.9103 - val_loss: 0.7792 - val_accuracy: 0.8047
# Epoch 97/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.9093
# Epoch 97: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 414ms/step - loss: 0.2311 - accuracy: 0.9093 - val_loss: 0.7303 - val_accuracy: 0.8125
# Epoch 98/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9118
# Epoch 98: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 366ms/step - loss: 0.2153 - accuracy: 0.9118 - val_loss: 0.9088 - val_accuracy: 0.7734
# Epoch 99/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9037
# Epoch 99: val_loss did not improve from 0.39868
# 31/31 [==============================] - 13s 410ms/step - loss: 0.2301 - accuracy: 0.9037 - val_loss: 0.8068 - val_accuracy: 0.7891
# Epoch 100/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.9057
# Epoch 100: val_loss did not improve from 0.39868
# 31/31 [==============================] - 11s 367ms/step - loss: 0.2311 - accuracy: 0.9057 - val_loss: 0.7323 - val_accuracy: 0.8125

# %%
# evaluation

# load testing set
test_metadata_filename = "test.csv"
df_test = pd.read_csv(test_metadata_filename)
n_testing_samples = len(df_test)
print("Number of testing samples:", n_testing_samples)
test_ds = tf.data.Dataset.from_tensor_slices((df_test["filepath"], df_test["label"]))

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()

  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  return ds


test_ds = test_ds.map(process_path)
test_ds = prepare_for_testing(test_ds, cache="test-cached-data")
# Out:
# Number of testing samples: 600

# %%
# convert testing set to numpy array to fit in memory (don't do that when testing
# set is too large)
y_test = np.zeros((n_testing_samples,))
X_test = np.zeros((n_testing_samples, 299, 299, 3))
for i, (img, label) in enumerate(test_ds.take(n_testing_samples)):
  # print(img.shape, label.shape)
  X_test[i] = img
  y_test[i] = label.numpy()

print("y_test.shape:", y_test.shape)
# Out:
# y_test.shape: (600,)

# %%
# load the weights with the least loss
m.load_weights("benign-vs-malignant_64_rmsprop_0.399.h5")

# %%
print("Evaluating the model...")
loss, accuracy = m.evaluate(X_test, y_test, verbose=0)
print("Loss:", loss, "  Accuracy:", accuracy)
# Out:
# Evaluating the model...
# Loss: 0.4570918381214142   Accuracy: 0.7950000166893005

# %%
from sklearn.metrics import accuracy_score

def get_predictions(threshold=None):
  """
  Returns predictions for binary classification given `threshold`
  For instance, if threshold is 0.3, then it'll output 1 (malignant) for that sample if
  the probability of 1 is 30% or more (instead of 50%)
  """
  y_pred = m.predict(X_test)
  if not threshold:
    threshold = 0.5
  result = np.zeros((n_testing_samples,))
  for i in range(n_testing_samples):
    # test melanoma probability
    if y_pred[i][0] >= threshold:
      result[i] = 1
    # else, it's 0 (benign)
  return result

threshold = 0.23
# get predictions with 23% threshold
# which means if the model is 23% sure or more that is malignant,
# it's assigned as malignant, otherwise it's benign
y_pred = get_predictions(threshold)
accuracy_after = accuracy_score(y_test, y_pred)
print("Accuracy after setting the threshold:", accuracy_after)
# Out:
# 19/19 [==============================] - 3s 117ms/step
# Accuracy after setting the threshold: 0.7216666666666667

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc, confusion_matrix

def plot_confusion_matrix(y_test, y_pred):
  cmn = confusion_matrix(y_test, y_pred)
  # Normalise
  cmn = cmn.astype('float') / cmn.sum(axis=1)[:, np.newaxis]
  # print it
  print(cmn)
  fig, ax = plt.subplots(figsize=(10,10))
  sns.heatmap(cmn, annot=True, fmt='.2f',
              xticklabels=[f"pred_{c}" for c in class_names],
              yticklabels=[f"true_{c}" for c in class_names],
              cmap="Blues"
              )
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  # plot the resulting confusion matrix
  plt.show()


def plot_roc_auc(y_true, y_pred):
    """
    This function plots the ROC curves and provides the scores.
    """
    # prepare for figure
    plt.figure()
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    # obtain ROC AUC
    roc_auc = auc(fpr, tpr)
    # print score
    print(f"ROC AUC: {roc_auc:.3f}")
    # plot ROC curve
    plt.plot(fpr, tpr, color="blue", lw=2,
                label='ROC curve (area = {f:.2f})'.format(d=1, f=roc_auc))
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curves')
    plt.legend(loc="lower right")
    plt.show()

plot_confusion_matrix(y_test, y_pred)
plot_roc_auc(y_test, y_pred)
sensitivity = sensitivity_score(y_test, y_pred)
specificity = specificity_score(y_test, y_pred)

print("Melanoma Sensitivity:", sensitivity)
print("Melanoma Specificity:", specificity)
# Out:
# [[0.75776398 0.24223602]
#  [0.42735043 0.57264957]]
# ROC AUC: 0.665
# Melanoma Sensitivity: 0.5726495726495726
# Melanoma Specificity: 0.7577639751552795

# %%
def plot_images(X_test, y_pred, y_test):
  predicted_class_names = np.array([class_names[int(round(id))] for id in y_pred])
  # some nice plotting
  plt.figure(figsize=(10,9))
  for n in range(30, 60):
      plt.subplot(6,5,n-30+1)
      plt.subplots_adjust(hspace = 0.3)
      plt.imshow(X_test[n])
      # get the predicted label
      predicted_label = predicted_class_names[n]
      # get the actual true label
      true_label = class_names[int(round(y_test[n]))]
      if predicted_label == true_label:
          color = "blue"
          title = predicted_label.title()
      else:
          color = "red"
          title = f"{predicted_label.title()}, true:{true_label.title()}"
      plt.title(title, color=color)
      plt.axis('off')
  _ = plt.suptitle("Model predictions (blue: correct, red: incorrect)")
  plt.show()

plot_images(X_test, y_pred, y_test)

# %%
# a function given a function, it predicts the class of the image
def predict_image_class(img_path, model, threshold=0.5):
  img = tf.keras.preprocessing.image.load_img(img_path, target_size=(299, 299))
  img = tf.keras.preprocessing.image.img_to_array(img)
  img = tf.expand_dims(img, 0) # Create a batch
  img = tf.keras.applications.inception_v3.preprocess_input(img)
  img = tf.image.convert_image_dtype(img, tf.float32)
  predictions = model.predict(img)
  score = predictions.squeeze()
  if score >= threshold:
    print(f"This image is {100 * score:.2f}% malignant.")
  else:
    print(f"This image is {100 * (1 - score):.2f}% benign.")

  plt.imshow(img[0])
  plt.axis('off')
  plt.show()

# %%
predict_image_class("data/test/melanoma/ISIC_0013767.jpg", m)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 50.64% malignant.

# %%
predict_image_class("data/test/nevus/ISIC_0012092.jpg", m)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 87.73% benign.

# %%
predict_image_class("data/test/seborrheic_keratosis/ISIC_0012136.jpg", m)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 95.72% benign.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
m.save('/content/gdrive/My Drive/Colab Notebooks/model_skin.h5')
